# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Mike Davis\Desktop\Python\Salary.csv")

# %%
plt.rc('figure',figsize=(20,9))
figure,axis=plt.subplots(2,2)
axis[0,0].plot(df['YearsExperience'],df['Salary'])
axis[0,1].plot(df['YearsExperience'],df['Age'])
axis[1,0].bar(df['YearsExperience'],df['Developer'])
axis[1,1].bar(df['YearsExperience'],df['Gender'])
# Out:
# <BarContainer object of 35 artists>
